# %%
#Q1. Explain why we have to use the Exception class while creating a Custom Exception.
"""
1.Consistency with language conventions : 
This convention ensures consistency with the language's exception hierarchy and makes it easier for  other developers to understand and work with 
your code. It also follows the principle of code reusability and leverages the existing exception handling mechanisms provided by the language.

2.Inherit useful properties and behaviors:
By inheriting from the Exception class, your custom exception gains access to various properties and behaviors that are essential for
effective exception handling. These include the ability to store and retrieve error messages.

3.Compatibility with third-party libraries:
Many third-party libraries and frameworks are designed to work with the standard Exception class or its subclasses.
By adhering to the language conventions and inheriting from Exception, your custom exception can be easily integrated with these libraries.
"""

# %%
#Q2. Write a python program to print Python Exception Hierarchy.
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
#             SSLError
# ...

# %%
#Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
"""
The ArithmeticError class in Python is the base class for exceptions that occur during arithmetic operations. 
It represents a broad category of errors related to mathematical calculations.
"""

"""
1.ZeroDivisionError: This exception is raised when division or modulo operation is performed with zero as the divisor.
"""
try:
    result = 10 / 0
except ZeroDivisionError as error:
    print("Error:", error)
# Out:
# Error: division by zero

# %%
"""
2.The FloatingPointError class in Python is a subclass of ArithmeticError that specifically handles errors related to floating-point 
arithmetic operations. It is raised when an error occurs during floating-point calculations
"""

import math

try:
    result = math.sqrt(-1)
except ValueError as error:
    print("Error:", error)
# Out:
# Error: math domain error

# %%
#Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

"""
The LookupError class in Python is the base class for exceptions that occur when a lookup or indexing operation fails. 
It represents a category of errors related to accessing elements or values using keys or indices that are not found or are out of range
"""

"""
1.KeyError: This exception is raised when a dictionary key or a set element is not found
"""
my_dict = {"name": "John", "age": 30}

try:
    value = my_dict["city"]
except KeyError as error:
    print("Error:", error)
# Out:
# Error: 'city'

# %%
"""
2.IndexError: This exception is raised when an index is out of range for a sequence like a list or a string.
"""
my_list = [1, 2, 3]

try:
    value = my_list[5]
except IndexError as error:
    print("Error:", error)
# Out:
# Error: list index out of range

# %%
#Q5. Explain ImportError. What is ModuleNotFoundError?
"""
ImportError is an exception in Python that is raised when an import statement fails to locate and import a module. 
It indicates that there was an issue with importing a module, either because the module does not exist, or there was an error in the import process
"""
try:
    import non_existent_module
except ImportError as error:
    print("Error:", error)
# Out:
# Error: No module named 'non_existent_module'

# %%
#Q6. List down some best practices for exception handling in python.
"""
1.Catch specific exceptions
2.Keep exception handling code minimal
3.Handle exceptions at an appropriate level
4.Use finally for cleanup
5.Log exceptions
6.Follow language and library conventions
"""
